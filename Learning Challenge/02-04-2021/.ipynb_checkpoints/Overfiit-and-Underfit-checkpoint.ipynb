# %%
# Importing

import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.4.1

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
# Downloading the Dataset

gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
  print(features[0])
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset shapes: ((28,), ()), types: (tf.float32, tf.float32)>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.0123s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4858,  binary_crossentropy:0.7288,  loss:0.7288,  val_accuracy:0.5060,  val_binary_crossentropy:0.7151,  val_loss:0.7151,
# ....................................................................................................
# Epoch: 100, accuracy:0.6045,  binary_crossentropy:0.6251,  loss:0.6251,  val_accuracy:0.5730,  val_binary_crossentropy:0.6264,  val_loss:0.6264,
# ....................................................................................................
# Epoch: 200, accuracy:0.6230,  binary_crossentropy:0.6129,  loss:0.6129,  val_accuracy:0.6100,  val_binary_crossentropy:0.6193,  val_loss:0.6193,
# ....................................................................................................
# Epoch: 300, accuracy:0.6324,  binary_crossentropy:0.6047,  loss:0.6047,  val_accuracy:0.6120,  val_binary_crossentropy:0.6133,  val_loss:0.6133,
# ....................................................................................................
# Epoch: 400, accuracy:0.6500,  binary_crossentropy:0.5967,  loss:0.5967,  val_accuracy:0.6260,  val_binary_crossentropy:0.6072,  val_loss:0.6072,
# ....................................................................................................
# Epoch: 500, accuracy:0.6640,  binary_crossentropy:0.5905,  loss:0.5905,  val_accuracy:0.6200,  val_binary_crossentropy:0.6038,  val_loss:0.6038,
# ....................................................................................................
# Epoch: 600, accuracy:0.6625,  binary_crossentropy:0.5874,  loss:0.5874,  val_accuracy:0.6340,  val_binary_crossentropy:0.5995,  val_loss:0.5995,
# ....................................................................................................
# Epoch: 700, accuracy:0.6694,  binary_crossentropy:0.5834,  loss:0.5834,  val_accuracy:0.6630,  val_binary_crossentropy:0.5930,  val_loss:0.5930,
# ....................................................................................................
# Epoch: 800, accuracy:0.6704,  binary_crossentropy:0.5809,  loss:0.5809,  val_accuracy:0.6680,  val_binary_crossentropy:0.5919,  val_loss:0.5919,
# ....................................................................................................
# Epoch: 900, accuracy:0.6720,  binary_crossentropy:0.5793,  loss:0.5793,  val_accuracy:0.6730,  val_binary_crossentropy:0.5903,  val_loss:0.5903,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6760,  binary_crossentropy:0.5776,  loss:0.5776,  val_accuracy:0.6800,  val_binary_crossentropy:0.5898,  val_loss:0.5898,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6795,  binary_crossentropy:0.5765,  loss:0.5765,  val_accuracy:0.6630,  val_binary_crossentropy:0.5887,  val_loss:0.5887,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6831,  binary_crossentropy:0.5748,  loss:0.5748,  val_accuracy:0.6660,  val_binary_crossentropy:0.5885,  val_loss:0.5885,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6837,  binary_crossentropy:0.5740,  loss:0.5740,  val_accuracy:0.6670,  val_binary_crossentropy:0.5880,  val_loss:0.5880,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6833,  binary_crossentropy:0.5726,  loss:0.5726,  val_accuracy:0.6770,  val_binary_crossentropy:0.5867,  val_loss:0.5867,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6864,  binary_crossentropy:0.5718,  loss:0.5718,  val_accuracy:0.6660,  val_binary_crossentropy:0.5884,  val_loss:0.5884,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6834,  binary_crossentropy:0.5713,  loss:0.5713,  val_accuracy:0.6750,  val_binary_crossentropy:0.5860,  val_loss:0.5860,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6850,  binary_crossentropy:0.5704,  loss:0.5704,  val_accuracy:0.6710,  val_binary_crossentropy:0.5861,  val_loss:0.5861,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6855,  binary_crossentropy:0.5695,  loss:0.5695,  val_accuracy:0.6760,  val_binary_crossentropy:0.5840,  val_loss:0.5840,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6819,  binary_crossentropy:0.5691,  loss:0.5691,  val_accuracy:0.6760,  val_binary_crossentropy:0.5841,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6872,  binary_crossentropy:0.5681,  loss:0.5681,  val_accuracy:0.6760,  val_binary_crossentropy:0.5834,  val_loss:0.5834,
# ....................................................................................................
# Epoch: 2100, accuracy:0.6842,  binary_crossentropy:0.5677,  loss:0.5677,  val_accuracy:0.6800,  val_binary_crossentropy:0.5829,  val_loss:0.5829,
# ....................................................................................................
# Epoch: 2200, accuracy:0.6850,  binary_crossentropy:0.5669,  loss:0.5669,  val_accuracy:0.6760,  val_binary_crossentropy:0.5825,  val_loss:0.5825,
# ....................................................................................................
# Epoch: 2300, accuracy:0.6848,  binary_crossentropy:0.5664,  loss:0.5664,  val_accuracy:0.6760,  val_binary_crossentropy:0.5818,  val_loss:0.5818,
# ....................................................................................................
# Epoch: 2400, accuracy:0.6864,  binary_crossentropy:0.5662,  loss:0.5662,  val_accuracy:0.6750,  val_binary_crossentropy:0.5830,  val_loss:0.5830,
# ....................................................................................................
# Epoch: 2500, accuracy:0.6894,  binary_crossentropy:0.5657,  loss:0.5657,  val_accuracy:0.6750,  val_binary_crossentropy:0.5826,  val_loss:0.5826,
# ....................................................................................................
# Epoch: 2600, accuracy:0.6806,  binary_crossentropy:0.5653,  loss:0.5653,  val_accuracy:0.6860,  val_binary_crossentropy:0.5813,  val_loss:0.5813,
# ....................................................................................................
# Epoch: 2700, accuracy:0.6845,  binary_crossentropy:0.5645,  loss:0.5645,  val_accuracy:0.6810,  val_binary_crossentropy:0.5816,  val_loss:0.5816,
# ....................................................................................................
# Epoch: 2800, accuracy:0.6844,  binary_crossentropy:0.5643,  loss:0.5643,  val_accuracy:0.6840,  val_binary_crossentropy:0.5798,  val_loss:0.5798,
# ....................................................................................................
# Epoch: 2900, accuracy:0.6865,  binary_crossentropy:0.5637,  loss:0.5637,  val_accuracy:0.6840,  val_binary_crossentropy:0.5806,  val_loss:0.5806,
# ....................................................................................................
# Epoch: 3000, accuracy:0.6849,  binary_crossentropy:0.5634,  loss:0.5634,  val_accuracy:0.6870,  val_binary_crossentropy:0.5799,  val_loss:0.5799,
# ....................................................................................................
# Epoch: 3100, accuracy:0.6860,  binary_crossentropy:0.5628,  loss:0.5628,  val_accuracy:0.6840,  val_binary_crossentropy:0.5803,  val_loss:0.5803,
# ....................................................................................................
# Epoch: 3200, accuracy:0.6826,  binary_crossentropy:0.5627,  loss:0.5627,  val_accuracy:0.6880,  val_binary_crossentropy:0.5791,  val_loss:0.5791,
# ....................................................................................................
# Epoch: 3300, accuracy:0.6888,  binary_crossentropy:0.5621,  loss:0.5621,  val_accuracy:0.6850,  val_binary_crossentropy:0.5789,  val_loss:0.5789,
# ....................................................................................................
# Epoch: 3400, accuracy:0.6886,  binary_crossentropy:0.5616,  loss:0.5616,  val_accuracy:0.6870,  val_binary_crossentropy:0.5790,  val_loss:0.5790,
# ....................................................................................................
# Epoch: 3500, accuracy:0.6897,  binary_crossentropy:0.5615,  loss:0.5615,  val_accuracy:0.6830,  val_binary_crossentropy:0.5791,  val_loss:0.5791,
# ....................................................................................................
# Epoch: 3600, accuracy:0.6873,  binary_crossentropy:0.5610,  loss:0.5610,  val_accuracy:0.6920,  val_binary_crossentropy:0.5783,  val_loss:0.5783,
# ....................................................................................................
# Epoch: 3700, accuracy:0.6856,  binary_crossentropy:0.5608,  loss:0.5608,  val_accuracy:0.6980,  val_binary_crossentropy:0.5775,  val_loss:0.5775,
# ....................................................................................................
# Epoch: 3800, accuracy:0.6888,  binary_crossentropy:0.5602,  loss:0.5602,  val_accuracy:0.6930,  val_binary_crossentropy:0.5780,  val_loss:0.5780,
# ....................................................................................................
# Epoch: 3900, accuracy:0.6919,  binary_crossentropy:0.5600,  loss:0.5600,  val_accuracy:0.6910,  val_binary_crossentropy:0.5781,  val_loss:0.5781,
# ....................................................................................................
# Epoch: 4000, accuracy:0.6925,  binary_crossentropy:0.5597,  loss:0.5597,  val_accuracy:0.6920,  val_binary_crossentropy:0.5777,  val_loss:0.5777,
# ....................................................................................................
# Epoch: 4100, accuracy:0.6937,  binary_crossentropy:0.5594,  loss:0.5594,  val_accuracy:0.6900,  val_binary_crossentropy:0.5774,  val_loss:0.5774,
# ....................................................................................................
# Epoch: 4200, accuracy:0.6921,  binary_crossentropy:0.5591,  loss:0.5591,  val_accuracy:0.6960,  val_binary_crossentropy:0.5768,  val_loss:0.5768,
# ....................................................................................................
# Epoch: 4300, accuracy:0.6881,  binary_crossentropy:0.5588,  loss:0.5588,  val_accuracy:0.6940,  val_binary_crossentropy:0.5768,  val_loss:0.5768,
# ....................................................................................................
# Epoch: 4400, accuracy:0.6895,  binary_crossentropy:0.5586,  loss:0.5586,  val_accuracy:0.6950,  val_binary_crossentropy:0.5767,  val_loss:0.5767,
# ....................................................................................................
# Epoch: 4500, accuracy:0.6931,  binary_crossentropy:0.5582,  loss:0.5582,  val_accuracy:0.6950,  val_binary_crossentropy:0.5764,  val_loss:0.5764,
# ....................................................................................................
# Epoch: 4600, accuracy:0.6941,  binary_crossentropy:0.5579,  loss:0.5579,  val_accuracy:0.6920,  val_binary_crossentropy:0.5764,  val_loss:0.5764,
# ....................................................................................................
# Epoch: 4700, accuracy:0.6949,  binary_crossentropy:0.5579,  loss:0.5579,  val_accuracy:0.6930,  val_binary_crossentropy:0.5768,  val_loss:0.5768,
# ....................................................................................................
# Epoch: 4800, accuracy:0.6932,  binary_crossentropy:0.5574,  loss:0.5574,  val_accuracy:0.6920,  val_binary_crossentropy:0.5759,  val_loss:0.5759,
# ....................................................................................................
# Epoch: 4900, accuracy:0.6899,  binary_crossentropy:0.5573,  loss:0.5573,  val_accuracy:0.6950,  val_binary_crossentropy:0.5759,  val_loss:0.5759,
# ....................................................................................................
# Epoch: 5000, accuracy:0.6909,  binary_crossentropy:0.5570,  loss:0.5570,  val_accuracy:0.6940,  val_binary_crossentropy:0.5757,  val_loss:0.5757,
# ....................................................................................................
# Epoch: 5100, accuracy:0.6913,  binary_crossentropy:0.5567,  loss:0.5567,  val_accuracy:0.6920,  val_binary_crossentropy:0.5759,  val_loss:0.5759,
# ....................................................................................................
# Epoch: 5200, accuracy:0.6934,  binary_crossentropy:0.5566,  loss:0.5566,  val_accuracy:0.6900,  val_binary_crossentropy:0.5761,  val_loss:0.5761,
# ....................................................................................................
# Epoch: 5300, accuracy:0.6937,  binary_crossentropy:0.5563,  loss:0.5563,  val_accuracy:0.6920,  val_binary_crossentropy:0.5757,  val_loss:0.5757,
# ....................................................................................................
# Epoch: 5400, accuracy:0.6949,  binary_crossentropy:0.5562,  loss:0.5562,  val_accuracy:0.6950,  val_binary_crossentropy:0.5749,  val_loss:0.5749,
# ....................................................................................................
# Epoch: 5500, accuracy:0.6943,  binary_crossentropy:0.5560,  loss:0.5560,  val_accuracy:0.6960,  val_binary_crossentropy:0.5750,  val_loss:0.5750,
# ....................................................................................................
# Epoch: 5600, accuracy:0.6958,  binary_crossentropy:0.5558,  loss:0.5558,  val_accuracy:0.6950,  val_binary_crossentropy:0.5750,  val_loss:0.5750,
# ....................................................................................................
# Epoch: 5700, accuracy:0.6977,  binary_crossentropy:0.5562,  loss:0.5562,  val_accuracy:0.6850,  val_binary_crossentropy:0.5760,  val_loss:0.5760,
# ....................................................................................................
# Epoch: 5800, accuracy:0.6915,  binary_crossentropy:0.5556,  loss:0.5556,  val_accuracy:0.6910,  val_binary_crossentropy:0.5756,  val_loss:0.5756,
# ....................................................................................................
# Epoch: 5900, accuracy:0.6950,  binary_crossentropy:0.5553,  loss:0.5553,  val_accuracy:0.6930,  val_binary_crossentropy:0.5747,  val_loss:0.5747,
# ....................................................................................................
# Epoch: 6000, accuracy:0.6966,  binary_crossentropy:0.5551,  loss:0.5551,  val_accuracy:0.6960,  val_binary_crossentropy:0.5744,  val_loss:0.5744,
# ....................................................................................................
# Epoch: 6100, accuracy:0.6926,  binary_crossentropy:0.5549,  loss:0.5549,  val_accuracy:0.6950,  val_binary_crossentropy:0.5744,  val_loss:0.5744,
# ....................................................................................................
# Epoch: 6200, accuracy:0.6966,  binary_crossentropy:0.5549,  loss:0.5549,  val_accuracy:0.6940,  val_binary_crossentropy:0.5742,  val_loss:0.5742,
# ....................................................................................................
# Epoch: 6300, accuracy:0.6935,  binary_crossentropy:0.5547,  loss:0.5547,  val_accuracy:0.6950,  val_binary_crossentropy:0.5743,  val_loss:0.5743,
# ....................................................................................................
# Epoch: 6400, accuracy:0.6922,  binary_crossentropy:0.5546,  loss:0.5546,  val_accuracy:0.6940,  val_binary_crossentropy:0.5742,  val_loss:0.5742,
# ....................................................................................................
# Epoch: 6500, accuracy:0.6949,  binary_crossentropy:0.5543,  loss:0.5543,  val_accuracy:0.6950,  val_binary_crossentropy:0.5741,  val_loss:0.5741,
# .................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                464
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0018s vs `on_train_batch_end` time: 0.0128s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4908,  binary_crossentropy:0.7009,  loss:0.7009,  val_accuracy:0.4850,  val_binary_crossentropy:0.6850,  val_loss:0.6850,
# ....................................................................................................
# Epoch: 100, accuracy:0.6248,  binary_crossentropy:0.6159,  loss:0.6159,  val_accuracy:0.6060,  val_binary_crossentropy:0.6159,  val_loss:0.6159,
# ....................................................................................................
# Epoch: 200, accuracy:0.6645,  binary_crossentropy:0.5921,  loss:0.5921,  val_accuracy:0.6230,  val_binary_crossentropy:0.5977,  val_loss:0.5977,
# ....................................................................................................
# Epoch: 300, accuracy:0.6781,  binary_crossentropy:0.5773,  loss:0.5773,  val_accuracy:0.6480,  val_binary_crossentropy:0.5919,  val_loss:0.5919,
# ....................................................................................................
# Epoch: 400, accuracy:0.6832,  binary_crossentropy:0.5700,  loss:0.5700,  val_accuracy:0.6600,  val_binary_crossentropy:0.5911,  val_loss:0.5911,
# ....................................................................................................
# Epoch: 500, accuracy:0.6889,  binary_crossentropy:0.5643,  loss:0.5643,  val_accuracy:0.6610,  val_binary_crossentropy:0.5925,  val_loss:0.5925,
# ....................................................................................................
# Epoch: 600, accuracy:0.6949,  binary_crossentropy:0.5602,  loss:0.5602,  val_accuracy:0.6580,  val_binary_crossentropy:0.5936,  val_loss:0.5936,
# .................

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1856
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0028s vs `on_train_batch_end` time: 0.0158s). Check your callbacks.
#
# Epoch: 0, accuracy:0.4995,  binary_crossentropy:0.6798,  loss:0.6798,  val_accuracy:0.4980,  val_binary_crossentropy:0.6694,  val_loss:0.6694,
# ....................................................................................................
# Epoch: 100, accuracy:0.7126,  binary_crossentropy:0.5271,  loss:0.5271,  val_accuracy:0.6530,  val_binary_crossentropy:0.6172,  val_loss:0.6172,
# ....................................................................................................
# Epoch: 200, accuracy:0.7841,  binary_crossentropy:0.4344,  loss:0.4344,  val_accuracy:0.6550,  val_binary_crossentropy:0.7089,  val_loss:0.7089,
# ...............................................

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               14848
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5081,  binary_crossentropy:0.8262,  loss:0.8262,  val_accuracy:0.4820,  val_binary_crossentropy:0.6867,  val_loss:0.6867,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0025,  loss:0.0025,  val_accuracy:0.6580,  val_binary_crossentropy:1.7537,  val_loss:1.7537,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0002,  loss:0.0002,  val_accuracy:0.6580,  val_binary_crossentropy:2.4168,  val_loss:2.4168,
# .....................

# %%
# Plotting training and validation losses

plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
# Preventing Overfitting

shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# WindowsPath('C:/Users/fabch/AppData/Local/Temp/tmprilnts3p/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
# Adding Weight Regularization

l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5107,  binary_crossentropy:0.7642,  loss:2.2649,  val_accuracy:0.4890,  val_binary_crossentropy:0.6755,  val_loss:2.0808,
# ....................................................................................................
# Epoch: 100, accuracy:0.6593,  binary_crossentropy:0.5966,  loss:0.6187,  val_accuracy:0.6400,  val_binary_crossentropy:0.5879,  val_loss:0.6101,
# ....................................................................................................
# Epoch: 200, accuracy:0.6707,  binary_crossentropy:0.5826,  loss:0.6036,  val_accuracy:0.6360,  val_binary_crossentropy:0.5814,  val_loss:0.6025,
# ....................................................................................................
# Epoch: 300, accuracy:0.6796,  binary_crossentropy:0.5754,  loss:0.5973,  val_accuracy:0.6530,  val_binary_crossentropy:0.5784,  val_loss:0.6002,
# ....................................................................................................
# Epoch: 400, accuracy:0.6880,  binary_crossentropy:0.5698,  loss:0.5935,  val_accuracy:0.6800,  val_binary_crossentropy:0.5839,  val_loss:0.6085,
# ....................................................................................................
# Epoch: 500, accuracy:0.6966,  binary_crossentropy:0.5596,  loss:0.5860,  val_accuracy:0.6790,  val_binary_crossentropy:0.5704,  val_loss:0.5967,
# ....................................................................................................
# Epoch: 600, accuracy:0.7010,  binary_crossentropy:0.5521,  loss:0.5789,  val_accuracy:0.6790,  val_binary_crossentropy:0.5727,  val_loss:0.5994,
# ....................................................................................................
# Epoch: 700, accuracy:0.7041,  binary_crossentropy:0.5477,  loss:0.5750,  val_accuracy:0.6680,  val_binary_crossentropy:0.5810,  val_loss:0.6083,
# ....................................................................................................
# Epoch: 800, accuracy:0.7069,  binary_crossentropy:0.5466,  loss:0.5747,  val_accuracy:0.6740,  val_binary_crossentropy:0.5761,  val_loss:0.6042,
# ......

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
result = l2_model(features)
regularization_loss=tf.add_n(l2_model.losses)

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5124,  binary_crossentropy:0.7938,  loss:0.7938,  val_accuracy:0.5060,  val_binary_crossentropy:0.6721,  val_loss:0.6721,
# ....................................................................................................
# Epoch: 100, accuracy:0.6550,  binary_crossentropy:0.5955,  loss:0.5955,  val_accuracy:0.6740,  val_binary_crossentropy:0.5793,  val_loss:0.5793,
# ....................................................................................................
# Epoch: 200, accuracy:0.6919,  binary_crossentropy:0.5601,  loss:0.5601,  val_accuracy:0.7090,  val_binary_crossentropy:0.5841,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 300, accuracy:0.7221,  binary_crossentropy:0.5100,  loss:0.5100,  val_accuracy:0.6770,  val_binary_crossentropy:0.5940,  val_loss:0.5940,
# ................................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4995,  binary_crossentropy:0.8128,  loss:0.9714,  val_accuracy:0.5670,  val_binary_crossentropy:0.7245,  val_loss:0.8824,
# ....................................................................................................
# Epoch: 100, accuracy:0.6470,  binary_crossentropy:0.6048,  loss:0.6342,  val_accuracy:0.6350,  val_binary_crossentropy:0.5869,  val_loss:0.6162,
# ....................................................................................................
# Epoch: 200, accuracy:0.6616,  binary_crossentropy:0.5895,  loss:0.6149,  val_accuracy:0.6720,  val_binary_crossentropy:0.5730,  val_loss:0.5985,
# ....................................................................................................
# Epoch: 300, accuracy:0.6744,  binary_crossentropy:0.5795,  loss:0.6071,  val_accuracy:0.6850,  val_binary_crossentropy:0.5659,  val_loss:0.5936,
# ....................................................................................................
# Epoch: 400, accuracy:0.6807,  binary_crossentropy:0.5782,  loss:0.6077,  val_accuracy:0.6840,  val_binary_crossentropy:0.5712,  val_loss:0.6008,
# ....................................................................................................
# Epoch: 500, accuracy:0.6837,  binary_crossentropy:0.5720,  loss:0.6030,  val_accuracy:0.6750,  val_binary_crossentropy:0.5489,  val_loss:0.5799,
# ....................................................................................................
# Epoch: 600, accuracy:0.6805,  binary_crossentropy:0.5699,  loss:0.6028,  val_accuracy:0.6820,  val_binary_crossentropy:0.5540,  val_loss:0.5868,
# ....................................................................................................
# Epoch: 700, accuracy:0.6847,  binary_crossentropy:0.5661,  loss:0.6007,  val_accuracy:0.6870,  val_binary_crossentropy:0.5458,  val_loss:0.5804,
# ....................................................................................................
# Epoch: 800, accuracy:0.6898,  binary_crossentropy:0.5581,  loss:0.5938,  val_accuracy:0.7050,  val_binary_crossentropy:0.5436,  val_loss:0.5792,
# ....................................................................................................
# Epoch: 900, accuracy:0.6935,  binary_crossentropy:0.5568,  loss:0.5943,  val_accuracy:0.6900,  val_binary_crossentropy:0.5496,  val_loss:0.5871,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6960,  binary_crossentropy:0.5530,  loss:0.5918,  val_accuracy:0.7050,  val_binary_crossentropy:0.5398,  val_loss:0.5786,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6959,  binary_crossentropy:0.5512,  loss:0.5911,  val_accuracy:0.6930,  val_binary_crossentropy:0.5438,  val_loss:0.5837,
# .....................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)
