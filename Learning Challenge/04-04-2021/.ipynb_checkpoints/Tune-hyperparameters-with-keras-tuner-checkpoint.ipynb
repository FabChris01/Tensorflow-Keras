# %%
# importing

import tensorflow as tf
from tensorflow import keras
import kerastuner as kt

# %%
(img_train, label_train), (img_test, label_test) = keras.datasets.fashion_mnist.load_data()

# %%
# Normalize pixel values between 0 and 1
img_train = img_train.astype('float32') / 255.0
img_test = img_test.astype('float32') / 255.0

# %%
def model_builder(hp):
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=(28, 28)))

  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(10))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(img_train, label_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 30 Complete [00h 00m 14s]
# val_accuracy: 0.8861666917800903
#
# Best val_accuracy So Far: 0.8919166922569275
# Total elapsed time: 00h 03m 13s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 256 and the optimal learning rate for the optimizer
# is 0.001.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(img_train, label_train, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.6156 - accuracy: 0.7850 - val_loss: 0.3858 - val_accuracy: 0.8611
# Epoch 2/50
# 1500/1500 [==============================] - 1s 903us/step - loss: 0.3881 - accuracy: 0.8594 - val_loss: 0.3795 - val_accuracy: 0.8618
# Epoch 3/50
# 1500/1500 [==============================] - 1s 862us/step - loss: 0.3313 - accuracy: 0.8783 - val_loss: 0.3891 - val_accuracy: 0.8493
# Epoch 4/50
# 1500/1500 [==============================] - 1s 850us/step - loss: 0.3182 - accuracy: 0.8820 - val_loss: 0.3285 - val_accuracy: 0.8822
# Epoch 5/50
# 1500/1500 [==============================] - 1s 839us/step - loss: 0.2902 - accuracy: 0.8927 - val_loss: 0.3242 - val_accuracy: 0.8838
# Epoch 6/50
# 1500/1500 [==============================] - 1s 863us/step - loss: 0.2755 - accuracy: 0.8984 - val_loss: 0.3264 - val_accuracy: 0.8862
# Epoch 7/50
# 1500/1500 [==============================] - 1s 867us/step - loss: 0.2602 - accuracy: 0.9031 - val_loss: 0.3157 - val_accuracy: 0.8863
# Epoch 8/50
# 1500/1500 [==============================] - 1s 859us/step - loss: 0.2431 - accuracy: 0.9076 - val_loss: 0.2987 - val_accuracy: 0.8930
# Epoch 9/50
# 1500/1500 [==============================] - 1s 876us/step - loss: 0.2364 - accuracy: 0.9118 - val_loss: 0.3166 - val_accuracy: 0.8897
# Epoch 10/50
# 1500/1500 [==============================] - 1s 862us/step - loss: 0.2269 - accuracy: 0.9139 - val_loss: 0.3309 - val_accuracy: 0.8838
# Epoch 11/50
# 1500/1500 [==============================] - 1s 857us/step - loss: 0.2095 - accuracy: 0.9222 - val_loss: 0.3063 - val_accuracy: 0.8879
# Epoch 12/50
# 1500/1500 [==============================] - 1s 853us/step - loss: 0.2128 - accuracy: 0.9184 - val_loss: 0.3395 - val_accuracy: 0.8832
# Epoch 13/50
# 1500/1500 [==============================] - 1s 846us/step - loss: 0.2018 - accuracy: 0.9244 - val_loss: 0.3280 - val_accuracy: 0.8915
# Epoch 14/50
# 1500/1500 [==============================] - 1s 865us/step - loss: 0.1930 - accuracy: 0.9273 - val_loss: 0.3297 - val_accuracy: 0.8921
# Epoch 15/50
# 1500/1500 [==============================] - 1s 863us/step - loss: 0.1877 - accuracy: 0.9300 - val_loss: 0.3455 - val_accuracy: 0.8871
# Epoch 16/50
# 1500/1500 [==============================] - 1s 853us/step - loss: 0.1847 - accuracy: 0.9318 - val_loss: 0.3439 - val_accuracy: 0.8901
# Epoch 17/50
# 1500/1500 [==============================] - 1s 853us/step - loss: 0.1758 - accuracy: 0.9344 - val_loss: 0.3418 - val_accuracy: 0.8933
# Epoch 18/50
# 1500/1500 [==============================] - 1s 846us/step - loss: 0.1692 - accuracy: 0.9354 - val_loss: 0.3436 - val_accuracy: 0.8937
# Epoch 19/50
# 1500/1500 [==============================] - 1s 833us/step - loss: 0.1636 - accuracy: 0.9384 - val_loss: 0.3539 - val_accuracy: 0.8910
# Epoch 20/50
# 1500/1500 [==============================] - 1s 856us/step - loss: 0.1568 - accuracy: 0.9426 - val_loss: 0.3517 - val_accuracy: 0.8898
# Epoch 21/50
# 1500/1500 [==============================] - 1s 855us/step - loss: 0.1541 - accuracy: 0.9424 - val_loss: 0.3643 - val_accuracy: 0.8912
# Epoch 22/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1506 - accuracy: 0.9429 - val_loss: 0.3580 - val_accuracy: 0.8892
# Epoch 23/50
# 1500/1500 [==============================] - 1s 885us/step - loss: 0.1447 - accuracy: 0.9441 - val_loss: 0.3728 - val_accuracy: 0.8919
# Epoch 24/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1438 - accuracy: 0.9455 - val_loss: 0.3592 - val_accuracy: 0.8919
# Epoch 25/50
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1365 - accuracy: 0.9486 - val_loss: 0.3964 - val_accuracy: 0.8840
# Epoch 26/50
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1325 - accuracy: 0.9514 - val_loss: 0.3733 - val_accuracy: 0.8947
# Epoch 27/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1268 - accuracy: 0.9520 - val_loss: 0.3791 - val_accuracy: 0.8929
# Epoch 28/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1243 - accuracy: 0.9523 - val_loss: 0.3980 - val_accuracy: 0.8942
# Epoch 29/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1199 - accuracy: 0.9553 - val_loss: 0.3797 - val_accuracy: 0.8951
# Epoch 30/50
# 1500/1500 [==============================] - 1s 912us/step - loss: 0.1138 - accuracy: 0.9580 - val_loss: 0.4218 - val_accuracy: 0.8876
# Epoch 31/50
# 1500/1500 [==============================] - 1s 902us/step - loss: 0.1126 - accuracy: 0.9578 - val_loss: 0.4156 - val_accuracy: 0.8888
# Epoch 32/50
# 1500/1500 [==============================] - 1s 903us/step - loss: 0.1056 - accuracy: 0.9617 - val_loss: 0.4553 - val_accuracy: 0.8871
# Epoch 33/50
# 1500/1500 [==============================] - 1s 915us/step - loss: 0.1106 - accuracy: 0.9585 - val_loss: 0.4458 - val_accuracy: 0.8905
# Epoch 34/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1083 - accuracy: 0.9592 - val_loss: 0.4093 - val_accuracy: 0.8962
# Epoch 35/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0987 - accuracy: 0.9623 - val_loss: 0.4670 - val_accuracy: 0.8878
# Epoch 36/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1010 - accuracy: 0.9621 - val_loss: 0.4412 - val_accuracy: 0.8936
# Epoch 37/50
# 1500/1500 [==============================] - 1s 968us/step - loss: 0.0999 - accuracy: 0.9620 - val_loss: 0.4424 - val_accuracy: 0.8971
# Epoch 38/50
# 1500/1500 [==============================] - 1s 925us/step - loss: 0.0922 - accuracy: 0.9646 - val_loss: 0.4322 - val_accuracy: 0.8948
# Epoch 39/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0922 - accuracy: 0.9643 - val_loss: 0.4482 - val_accuracy: 0.8961
# Epoch 40/50
# 1500/1500 [==============================] - 1s 943us/step - loss: 0.0911 - accuracy: 0.9666 - val_loss: 0.4814 - val_accuracy: 0.8896
# Epoch 41/50
# 1500/1500 [==============================] - 1s 931us/step - loss: 0.0919 - accuracy: 0.9649 - val_loss: 0.4748 - val_accuracy: 0.8919
# Epoch 42/50
# 1500/1500 [==============================] - 1s 915us/step - loss: 0.0909 - accuracy: 0.9661 - val_loss: 0.4847 - val_accuracy: 0.8887
# Epoch 43/50
# 1500/1500 [==============================] - 1s 939us/step - loss: 0.0814 - accuracy: 0.9695 - val_loss: 0.4963 - val_accuracy: 0.8908
# Epoch 44/50
# 1500/1500 [==============================] - 1s 895us/step - loss: 0.0845 - accuracy: 0.9691 - val_loss: 0.4745 - val_accuracy: 0.8932
# Epoch 45/50
# 1500/1500 [==============================] - 1s 895us/step - loss: 0.0801 - accuracy: 0.9694 - val_loss: 0.4897 - val_accuracy: 0.8950
# Epoch 46/50
# 1500/1500 [==============================] - 1s 902us/step - loss: 0.0837 - accuracy: 0.9698 - val_loss: 0.4520 - val_accuracy: 0.8935
# Epoch 47/50
# 1500/1500 [==============================] - 1s 890us/step - loss: 0.0769 - accuracy: 0.9716 - val_loss: 0.5108 - val_accuracy: 0.8873
# Epoch 48/50
# 1500/1500 [==============================] - 1s 988us/step - loss: 0.0795 - accuracy: 0.9710 - val_loss: 0.5038 - val_accuracy: 0.8926
# Epoch 49/50
# 1500/1500 [==============================] - 1s 946us/step - loss: 0.0773 - accuracy: 0.9717 - val_loss: 0.5047 - val_accuracy: 0.8932
# Epoch 50/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0783 - accuracy: 0.9709 - val_loss: 0.5010 - val_accuracy: 0.8975
# Best epoch: 50

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(img_train, label_train, epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.6136 - accuracy: 0.7868 - val_loss: 0.4006 - val_accuracy: 0.8548
# Epoch 2/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3795 - accuracy: 0.8611 - val_loss: 0.3739 - val_accuracy: 0.8624
# Epoch 3/50
# 1500/1500 [==============================] - 1s 804us/step - loss: 0.3332 - accuracy: 0.8792 - val_loss: 0.3636 - val_accuracy: 0.8679
# Epoch 4/50
# 1500/1500 [==============================] - 1s 786us/step - loss: 0.3148 - accuracy: 0.8817 - val_loss: 0.3422 - val_accuracy: 0.8747
# Epoch 5/50
# 1500/1500 [==============================] - 1s 774us/step - loss: 0.2900 - accuracy: 0.8921 - val_loss: 0.3150 - val_accuracy: 0.8901
# Epoch 6/50
# 1500/1500 [==============================] - 1s 781us/step - loss: 0.2756 - accuracy: 0.8966 - val_loss: 0.3240 - val_accuracy: 0.8836
# Epoch 7/50
# 1500/1500 [==============================] - 1s 786us/step - loss: 0.2566 - accuracy: 0.9051 - val_loss: 0.3134 - val_accuracy: 0.8877
# Epoch 8/50
# 1500/1500 [==============================] - 1s 782us/step - loss: 0.2470 - accuracy: 0.9081 - val_loss: 0.3178 - val_accuracy: 0.8888
# Epoch 9/50
# 1500/1500 [==============================] - 1s 787us/step - loss: 0.2376 - accuracy: 0.9104 - val_loss: 0.3229 - val_accuracy: 0.8875
# Epoch 10/50
# 1500/1500 [==============================] - 1s 791us/step - loss: 0.2289 - accuracy: 0.9158 - val_loss: 0.3357 - val_accuracy: 0.8813
# Epoch 11/50
# 1500/1500 [==============================] - 1s 816us/step - loss: 0.2183 - accuracy: 0.9174 - val_loss: 0.3234 - val_accuracy: 0.8894
# Epoch 12/50
# 1500/1500 [==============================] - 1s 795us/step - loss: 0.2104 - accuracy: 0.9197 - val_loss: 0.3356 - val_accuracy: 0.8822
# Epoch 13/50
# 1500/1500 [==============================] - 1s 818us/step - loss: 0.2028 - accuracy: 0.9229 - val_loss: 0.3152 - val_accuracy: 0.8929
# Epoch 14/50
# 1500/1500 [==============================] - 1s 813us/step - loss: 0.1945 - accuracy: 0.9261 - val_loss: 0.3107 - val_accuracy: 0.8974
# Epoch 15/50
# 1500/1500 [==============================] - 1s 846us/step - loss: 0.1882 - accuracy: 0.9294 - val_loss: 0.3155 - val_accuracy: 0.8931
# Epoch 16/50
# 1500/1500 [==============================] - 1s 866us/step - loss: 0.1795 - accuracy: 0.9325 - val_loss: 0.3266 - val_accuracy: 0.8942
# Epoch 17/50
# 1500/1500 [==============================] - 1s 846us/step - loss: 0.1787 - accuracy: 0.9321 - val_loss: 0.3245 - val_accuracy: 0.8960
# Epoch 18/50
# 1500/1500 [==============================] - 1s 808us/step - loss: 0.1671 - accuracy: 0.9368 - val_loss: 0.3306 - val_accuracy: 0.8919
# Epoch 19/50
# 1500/1500 [==============================] - 1s 830us/step - loss: 0.1648 - accuracy: 0.9381 - val_loss: 0.3403 - val_accuracy: 0.8927
# Epoch 20/50
# 1500/1500 [==============================] - 1s 878us/step - loss: 0.1611 - accuracy: 0.9383 - val_loss: 0.3427 - val_accuracy: 0.8944
# Epoch 21/50
# 1500/1500 [==============================] - 1s 860us/step - loss: 0.1522 - accuracy: 0.9423 - val_loss: 0.3658 - val_accuracy: 0.8910
# Epoch 22/50
# 1500/1500 [==============================] - 1s 912us/step - loss: 0.1542 - accuracy: 0.9419 - val_loss: 0.3653 - val_accuracy: 0.8917
# Epoch 23/50
# 1500/1500 [==============================] - 1s 942us/step - loss: 0.1500 - accuracy: 0.9421 - val_loss: 0.3904 - val_accuracy: 0.8877
# Epoch 24/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1385 - accuracy: 0.9485 - val_loss: 0.3919 - val_accuracy: 0.8879
# Epoch 25/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1384 - accuracy: 0.9471 - val_loss: 0.3570 - val_accuracy: 0.8919
# Epoch 26/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1320 - accuracy: 0.9502 - val_loss: 0.3907 - val_accuracy: 0.8906
# Epoch 27/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1288 - accuracy: 0.9497 - val_loss: 0.3673 - val_accuracy: 0.8959
# Epoch 28/50
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1216 - accuracy: 0.9548 - val_loss: 0.3919 - val_accuracy: 0.8937
# Epoch 29/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1226 - accuracy: 0.9542 - val_loss: 0.3825 - val_accuracy: 0.8961
# Epoch 30/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1202 - accuracy: 0.9552 - val_loss: 0.3973 - val_accuracy: 0.8948
# Epoch 31/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1114 - accuracy: 0.9581 - val_loss: 0.4043 - val_accuracy: 0.8955
# Epoch 32/50
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.1152 - accuracy: 0.9562 - val_loss: 0.3846 - val_accuracy: 0.8999
# Epoch 33/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1075 - accuracy: 0.9597 - val_loss: 0.4401 - val_accuracy: 0.8938
# Epoch 34/50
# 1500/1500 [==============================] - 1s 824us/step - loss: 0.1104 - accuracy: 0.9591 - val_loss: 0.4186 - val_accuracy: 0.8913
# Epoch 35/50
# 1500/1500 [==============================] - 1s 831us/step - loss: 0.1016 - accuracy: 0.9621 - val_loss: 0.4133 - val_accuracy: 0.8947
# Epoch 36/50
# 1500/1500 [==============================] - 1s 833us/step - loss: 0.1045 - accuracy: 0.9623 - val_loss: 0.4427 - val_accuracy: 0.8903
# Epoch 37/50
# 1500/1500 [==============================] - 1s 827us/step - loss: 0.0993 - accuracy: 0.9631 - val_loss: 0.4366 - val_accuracy: 0.8883
# Epoch 38/50
# 1500/1500 [==============================] - 1s 811us/step - loss: 0.0929 - accuracy: 0.9656 - val_loss: 0.4806 - val_accuracy: 0.8881
# Epoch 39/50
# 1500/1500 [==============================] - 1s 828us/step - loss: 0.0968 - accuracy: 0.9629 - val_loss: 0.4485 - val_accuracy: 0.8967
# Epoch 40/50
# 1500/1500 [==============================] - 1s 843us/step - loss: 0.0935 - accuracy: 0.9650 - val_loss: 0.4921 - val_accuracy: 0.8892
# Epoch 41/50
# 1500/1500 [==============================] - 1s 843us/step - loss: 0.0889 - accuracy: 0.9668 - val_loss: 0.4436 - val_accuracy: 0.8954
# Epoch 42/50
# 1500/1500 [==============================] - 1s 854us/step - loss: 0.0882 - accuracy: 0.9668 - val_loss: 0.4797 - val_accuracy: 0.8893
# Epoch 43/50
# 1500/1500 [==============================] - 1s 835us/step - loss: 0.0842 - accuracy: 0.9686 - val_loss: 0.4732 - val_accuracy: 0.8874
# Epoch 44/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0839 - accuracy: 0.9684 - val_loss: 0.5347 - val_accuracy: 0.8788
# Epoch 45/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0843 - accuracy: 0.9685 - val_loss: 0.4678 - val_accuracy: 0.8950
# Epoch 46/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0790 - accuracy: 0.9706 - val_loss: 0.4749 - val_accuracy: 0.8934
# Epoch 47/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0823 - accuracy: 0.9695 - val_loss: 0.4823 - val_accuracy: 0.8947
# Epoch 48/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0779 - accuracy: 0.9703 - val_loss: 0.5070 - val_accuracy: 0.8889
# Epoch 49/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0793 - accuracy: 0.9712 - val_loss: 0.5045 - val_accuracy: 0.8956
# Epoch 50/50
# 1500/1500 [==============================] - 1s 967us/step - loss: 0.0760 - accuracy: 0.9711 - val_loss: 0.5336 - val_accuracy: 0.8905

# %%
eval_result = hypermodel.evaluate(img_test, label_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 313/313 [==============================] - 0s 863us/step - loss: 0.5956 - accuracy: 0.8840
# [test loss, test accuracy]: [0.5956405401229858, 0.8840000033378601]
